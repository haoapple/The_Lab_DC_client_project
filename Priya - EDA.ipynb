# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pv14 = pd.read_csv('./assets/pv/pv_2014.csv')

# %%
pv14.head()
# Out:
#    ADDRESS_ID BODY_STYLE DAY_OF_WEEK  HOLIDAY  ISSUE_TIME  \
# 0    811890.0         4D    THURSDAY      0.0      2320.0
# 1    814126.0         VA    THURSDAY      0.0      1204.0
# 2    804378.0        NaN    THURSDAY      0.0        52.0
# 3    802140.0         4D    THURSDAY      0.0      1237.0
# 4    813622.0         4D    THURSDAY      0.0       340.0
#
#                             LOCATION  MONTH_OF_YEAR    OBJECTID  ROWID_  \
# 0       BLOCK 100 R ST NE SOUTH SIDE            1.0  24640555.0  3467.0
# 1      1400 BLOCK W ST NW NORTH SIDE            1.0  24640556.0  3468.0
# 2  BLOCK 600 MORTON PL NE SOUTH SIDE            1.0  24640557.0  3469.0
# 3      3500 BLOCK R ST NW SOUTH SIDE            1.0  24640558.0  3470.0
# 4      BLOCK 2200 I ST NW NORTH SIDE            1.0  24640559.0  3471.0
#
#   RP_PLATE_STATE                ...                  VIOLATION_CODE  \
# 0             MD                ...                            P076
# ...

# %%
pv14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1443445 entries, 0 to 1443444
# Data columns (total 22 columns):
# ADDRESS_ID                           1443445 non-null float64
# BODY_STYLE                           1212740 non-null object
# DAY_OF_WEEK                          1443445 non-null object
# HOLIDAY                              1443445 non-null float64
# ISSUE_TIME                           1442669 non-null float64
# LOCATION                             1443445 non-null object
# MONTH_OF_YEAR                        1443445 non-null float64
# OBJECTID                             1443445 non-null float64
# ROWID_                               1443445 non-null float64
# RP_PLATE_STATE                       1441870 non-null object
# STREETSEGID                          1443424 non-null float64
# TICKET_ISSUE_DATE                    1443445 non-null object
# VIOLATION_CODE                       1443445 non-null object
# ...

# %%
pv14.isnull().sum().sort_values(ascending=False)
# Out:
# {"processingTime":"0.391 seconds"    1443445
# generating:{}}                       1443445
# status:"Processing"                  1443445
# BODY_STYLE                            230705
# VIOLATION_DESCRIPTION                  43948
# RP_PLATE_STATE                          1575
# ISSUE_TIME                               776
# STREETSEGID                               21
# WEEK_OF_YEAR                               0
# VIOLATION_CODE                             0
# TICKET_ISSUE_DATE                          0
# X                                          0
# XCOORD                                     0
# ROWID_                                     0
# OBJECTID                                   0
# MONTH_OF_YEAR                              0
# LOCATION                                   0
# Y                                          0
# HOLIDAY                                    0
# DAY_OF_WEEK                                0
# YCOORD                                     0
# ...

# %%
pv14.shape
# Out:
# (1443445, 22)

# %%
pv14.VIOLATION_DESCRIPTION.value_counts()
# Out:
# PARK AT EXPIRED METER                                 257691
# RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT      110164
# DISOBEYING OFFICIAL SIGN                              109877
# FAIL TO DISPLAY A MULTISPACE METER RECEIPT            100398
# NO PARKING STREET CLEANING                             75482
# NO STOPPING OR STANDING IN PM RUSH HOUR ZONE           67461
# FAILURE TO DISPLAY CURRENT TAGS                        61507
# NO PARKING ANYTIME                                     55122
# FAILURE TO SECURE DC TAGS                              39043
# PARK OVERTIME AT A METER                               38418
# NO STANDING ANYTIME                                    37603
# NO STOPPING OR STANDING IN AM RUSH HOUR ZONE           31200
# UNAUTHORIZED VEHICLE IN LOADING ZONE                   30947
# FAIL TO REPORT FOR INSPECTION.                         27245
# EXPIRATION TIME ON METER RECEIPT LAPSED                25908
# ...

# %%
pv15 = pd.read_csv('./assets/pv/pv_2015.csv')

# %%
pv15.head()
# Out:
#            X          Y  OBJECTID  ROWID_ DAY_OF_WEEK  HOLIDAY  WEEK_OF_YEAR  \
# 0 -77.034104  38.902522  24645888   10160      MONDAY        0             3
# 1 -76.954803  38.895033  24645889   10161      MONDAY        0             3
# 2 -77.026254  38.906209  24645890   10162      MONDAY        0             3
# 3 -77.015353  38.876132  24645891   10163      MONDAY        0             3
# 4 -77.028083  38.895579  24645892   10164      MONDAY        0             3
#
#    MONTH_OF_YEAR  ISSUE_TIME VIOLATION_CODE  \
# 0              1      2043.0           P170
# 1              1      2238.0           P172
# 2              1      1010.0           P170
# 3              1       702.0           P159
# 4              1      1231.0           P199
#
#                           VIOLATION_DESCRIPTION  \
# 0               FAILURE TO DISPLAY CURRENT TAGS
# 1                     FAILURE TO SECURE DC TAGS
# 2               FAILURE TO DISPLAY CURRENT TAGS
# ...

# %%
pv15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686306 entries, 0 to 1686305
# Data columns (total 19 columns):
# X                        1686306 non-null float64
# Y                        1686306 non-null float64
# OBJECTID                 1686306 non-null int64
# ROWID_                   1686306 non-null int64
# DAY_OF_WEEK              1686306 non-null object
# HOLIDAY                  1686306 non-null int64
# WEEK_OF_YEAR             1686306 non-null int64
# MONTH_OF_YEAR            1686306 non-null int64
# ISSUE_TIME               1685438 non-null float64
# VIOLATION_CODE           1686306 non-null object
# VIOLATION_DESCRIPTION    1637423 non-null object
# LOCATION                 1686306 non-null object
# RP_PLATE_STATE           1680708 non-null object
# BODY_STYLE               1640521 non-null object
# ADDRESS_ID               1686306 non-null int64
# STREETSEGID              1677720 non-null float64
# XCOORD                   1686306 non-null int64
# ...

# %%
pv15.isnull().sum().sort_values(ascending=False)
# Out:
# VIOLATION_DESCRIPTION    48883
# BODY_STYLE               45785
# STREETSEGID               8586
# RP_PLATE_STATE            5598
# ISSUE_TIME                 868
# TICKET_ISSUE_DATE            0
# WEEK_OF_YEAR                 0
# Y                            0
# OBJECTID                     0
# ROWID_                       0
# DAY_OF_WEEK                  0
# HOLIDAY                      0
# VIOLATION_CODE               0
# MONTH_OF_YEAR                0
# YCOORD                       0
# LOCATION                     0
# ADDRESS_ID                   0
# XCOORD                       0
# X                            0
# dtype: int64

# %%
pv15.shape
# Out:
# (1686306, 19)

# %%
pv15.VIOLATION_DESCRIPTION.value_counts()
# Out:
# PARK AT EXPIRED METER                                 225670
# FAIL TO DISPLAY A MULTISPACE METER RECEIPT            157575
# RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT      143724
# DISOBEYING OFFICIAL SIGN                              118790
# NO PARKING STREET CLEANING                             91451
# NO STOPPING OR STANDING IN PM RUSH HOUR ZONE           77970
# FAILURE TO DISPLAY CURRENT TAGS                        65231
# NO PARKING ANYTIME                                     61183
# PARK OVERTIME AT A METER                               61009
# UNAUTHORIZED VEHICLE IN LOADING ZONE                   58026
# FAILURE TO SECURE DC TAGS                              43362
# NO STANDING ANYTIME                                    43145
# NO STOPPING OR STANDING IN AM RUSH HOUR ZONE           35617
# EXPIRATION TIME ON METER RECEIPT LAPSED                32867
# PARK OVERTIME IN TIMED ZONE                            30910
# ...

# %%
pv16 = pd.read_csv('./assets/pv/pv_2016.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pv16.head()
# Out:
#    ADDRESS_ID BODY_STYLE DAY_OF_WEEK  HOLIDAY  ISSUE_TIME  \
# 0    809980.0         4D    THURSDAY      0.0      1207.0
# 1    803794.0         4D    THURSDAY      0.0      1530.0
# 2    804356.0         TK    THURSDAY      0.0      1115.0
# 3    810352.0         UT    THURSDAY      0.0      1602.0
# 4    811860.0         4D    THURSDAY      0.0      2128.0
#
#                               LOCATION  MONTH_OF_YEAR    OBJECTID     ROWID_  \
# 0         600 BLOCK G ST NE SOUTH SIDE            1.0  32187592.0  7769783.0
# 1         300 BLOCK I ST SE NORTH SIDE            1.0  32187593.0  7769784.0
# 2        1300 BLOCK Q ST NW NORTH SIDE            1.0  32187594.0  7769785.0
# 3  800 BLOCK CONSTITUTION AVE NW NORT*            1.0  32187595.0  7769786.0
# 4      1400 BLOCK EYE ST NW NORTH SIDE            1.0  32187596.0  7769787.0
#
#   RP_PLATE_STATE                       ...                        \
# 0             VA                       ...
# ...

# %%
pv16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1891974 entries, 0 to 1891973
# Data columns (total 23 columns):
# ADDRESS_ID                                        float64
# BODY_STYLE                                        object
# DAY_OF_WEEK                                       object
# HOLIDAY                                           float64
# ISSUE_TIME                                        float64
# LOCATION                                          object
# MONTH_OF_YEAR                                     float64
# OBJECTID                                          float64
# ROWID_                                            float64
# RP_PLATE_STATE                                    object
# STREETSEGID                                       float64
# TICKET_ISSUE_DATE                                 object
# VIOLATION_CODE                                    object
# VIOLATION_DESCRIPTION                             object
# ...

# %%
pv16.isnull().sum().sort_values(ascending=False)
# Out:
# {"processingTime":"1731.9746833333334 minutes"    1891974
# status:"Processing"                               1891974
# generating:{}}                                    1891974
# {"processingTime":"0.417 seconds"                 1891974
# ISSUE_TIME                                        1410994
# DAY_OF_WEEK                                       1410776
# HOLIDAY                                           1410776
# WEEK_OF_YEAR                                      1410776
# MONTH_OF_YEAR                                     1410776
# VIOLATION_DESCRIPTION                               64194
# BODY_STYLE                                          21200
# RP_PLATE_STATE                                      11512
# STREETSEGID                                          8207
# OBJECTID                                                0
# LOCATION                                                0
# TICKET_ISSUE_DATE                                       0
# ...

# %%
pv16.shape
# Out:
# (1891974, 23)

# %%
pv16.VIOLATION_DESCRIPTION.value_counts()
# Out:
# PARK AT EXPIRED METER                                 201972
# FAIL TO DISPLAY A MULTISPACE METER RECEIPT            200786
# DISOBEYING OFFICIAL SIGN                              141273
# RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT      120614
# NO PARKING STREET CLEANING                            110846
# NO STOPPING OR STANDING IN PM RUSH HOUR ZONE          100069
# FAILURE TO DISPLAY CURRENT TAGS                        81804
# NO PARKING ANYTIME                                     71042
# UNAUTHORIZED VEHICLE IN LOADING ZONE                   60707
# FAILURE TO SECURE DC TAGS                              54896
# PARK OVERTIME AT A METER                               51709
# NO STOPPING OR STANDING IN AM RUSH HOUR ZONE           47673
# NO STANDING ANYTIME                                    46185
# EXPIRATION TIME ON METER RECEIPT LAPSED                35476
# PARK OVERTIME IN TIMED ZONE                            32673
# ...

# %%
pv17 = pd.read_csv('./assets/pv/pv_2017.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pv17.head()
# Out:
#            X          Y  OBJECTID      ROWID_  DAY_OF_WEEK  HOLIDAY  \
# 0 -77.023954  38.887571    597586  14189653.0          NaN      NaN
# 1 -77.000579  38.877007    597587  14189656.0          NaN      NaN
# 2 -77.008124  38.952406    597588  14189657.0          NaN      NaN
# 3 -77.021718  38.927433    597589  14189658.0          NaN      NaN
# 4 -77.042586  38.898331    597590  14189660.0          NaN      NaN
#
#    WEEK_OF_YEAR  MONTH_OF_YEAR  ISSUE_TIME VIOLATION_CODE  \
# 0           NaN            NaN         NaN           P281
# 1           NaN            NaN         NaN           P269
# 2           NaN            NaN         NaN           P269
# 3           NaN            NaN         NaN           P259
# 4           NaN            NaN         NaN           P014
#
#                           VIOLATION_DESCRIPTION  \
# 0    FAIL TO DISPLAY A MULTISPACE METER RECEIPT
# 1                           NO STANDING ANYTIME
# 2                           NO STANDING ANYTIME
# ...

# %%
pv17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1404052 entries, 0 to 1404051
# Data columns (total 19 columns):
# X                        1404052 non-null float64
# Y                        1404052 non-null float64
# OBJECTID                 1404052 non-null int64
# ROWID_                   174954 non-null float64
# DAY_OF_WEEK              0 non-null float64
# HOLIDAY                  0 non-null float64
# WEEK_OF_YEAR             0 non-null float64
# MONTH_OF_YEAR            0 non-null float64
# ISSUE_TIME               0 non-null float64
# VIOLATION_CODE           1404052 non-null object
# VIOLATION_DESCRIPTION    1389544 non-null object
# LOCATION                 1404052 non-null object
# RP_PLATE_STATE           1393022 non-null object
# BODY_STYLE               173700 non-null object
# ADDRESS_ID               1404052 non-null int64
# STREETSEGID              1398855 non-null float64
# XCOORD                   1404052 non-null int64
# ...

# %%
pv17.shape
# Out:
# (1404052, 19)

# %%
pv17.isnull().sum().sort_values(ascending=False)
# Out:
# HOLIDAY                  1404052
# DAY_OF_WEEK              1404052
# ISSUE_TIME               1404052
# MONTH_OF_YEAR            1404052
# WEEK_OF_YEAR             1404052
# BODY_STYLE               1230352
# ROWID_                   1229098
# VIOLATION_DESCRIPTION      14508
# RP_PLATE_STATE             11030
# STREETSEGID                 5197
# TICKET_ISSUE_DATE              0
# Y                              0
# OBJECTID                       0
# VIOLATION_CODE                 0
# YCOORD                         0
# LOCATION                       0
# ADDRESS_ID                     0
# XCOORD                         0
# X                              0
# dtype: int64

# %%
pv17.VIOLATION_DESCRIPTION.value_counts()
# Out:
# FAIL TO DISPLAY A MULTISPACE METER RECEIPT            161265
# PARK AT EXPIRED METER                                 144967
# DISOBEYING OFFICIAL SIGN                               97544
# RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT       96849
# NO PARKING STREET CLEANING                             85162
# NO STOPPING OR STANDING IN PM RUSH HOUR ZONE           67802
# FAILURE TO DISPLAY CURRENT TAGS                        67126
# NO PARKING ANYTIME                                     52995
# UNAUTHORIZED VEHICLE IN LOADING ZONE                   42734
# FAILURE TO SECURE DC TAGS                              42728
# NO STANDING ANYTIME                                    37537
# PARK OVERTIME AT A METER                               34460
# NO STOPPING OR STANDING IN AM RUSH HOUR ZONE           32328
# NO FRONT TAGS.                                         28991
# PARKED WITHIN 25 FEET OF A STOP SIGN                   25514
# ...

# %%
pv18 = pd.read_csv('./assets/pv/pv_2018.csv')

# %%
pv18.head()
# Out:
#            X          Y  OBJECTID  ROWID_  DAY_OF_WEEK  HOLIDAY  WEEK_OF_YEAR  \
# 0 -77.031951  38.910027   3671201     NaN          NaN      NaN           NaN
# 1 -77.038084  38.907251   3671202     NaN          NaN      NaN           NaN
# 2 -77.040612  38.893548   3671203     NaN          NaN      NaN           NaN
# 3 -76.994366  38.893582   3671204     NaN          NaN      NaN           NaN
# 4 -77.033254  38.910396   3671205     NaN          NaN      NaN           NaN
#
#    MONTH_OF_YEAR  ISSUE_TIME VIOLATION_CODE  \
# 0            NaN         NaN           P169
# 1            NaN         NaN           P002
# 2            NaN         NaN           P039
# 3            NaN         NaN           P003
# 4            NaN         NaN           P012
#
#                               VIOLATION_DESCRIPTION  \
# 0                                     NO REAR TAGS.
# 1                            STAND OR PARK IN ALLEY
# 2                             PARK AT EXPIRED METER
# ...

# %%
pv18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207720 entries, 0 to 207719
# Data columns (total 19 columns):
# X                        207720 non-null float64
# Y                        207720 non-null float64
# OBJECTID                 207720 non-null int64
# ROWID_                   0 non-null float64
# DAY_OF_WEEK              0 non-null float64
# HOLIDAY                  0 non-null float64
# WEEK_OF_YEAR             0 non-null float64
# MONTH_OF_YEAR            0 non-null float64
# ISSUE_TIME               0 non-null float64
# VIOLATION_CODE           207720 non-null object
# VIOLATION_DESCRIPTION    200690 non-null object
# LOCATION                 207720 non-null object
# RP_PLATE_STATE           206336 non-null object
# BODY_STYLE               0 non-null float64
# ADDRESS_ID               207720 non-null int64
# STREETSEGID              206891 non-null float64
# XCOORD                   207720 non-null int64
# YCOORD                   207720 non-null int64
# ...

# %%
pv18.shape
# Out:
# (207720, 19)

# %%
pv18.isnull().sum().sort_values(ascending=False)
# Out:
# HOLIDAY                  207720
# BODY_STYLE               207720
# ROWID_                   207720
# DAY_OF_WEEK              207720
# ISSUE_TIME               207720
# MONTH_OF_YEAR            207720
# WEEK_OF_YEAR             207720
# VIOLATION_DESCRIPTION      7030
# RP_PLATE_STATE             1384
# STREETSEGID                 829
# TICKET_ISSUE_DATE             0
# Y                             0
# OBJECTID                      0
# VIOLATION_CODE                0
# YCOORD                        0
# LOCATION                      0
# ADDRESS_ID                    0
# XCOORD                        0
# X                             0
# dtype: int64

# %%
pv18.VIOLATION_DESCRIPTION.value_counts()
# Out:
# FAIL TO DISPLAY A MULTISPACE METER RECEIPT            27689
# PARK AT EXPIRED METER                                 22332
# RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT      18366
# DISOBEYING OFFICIAL SIGN                              12960
# FAILURE TO DISPLAY CURRENT TAGS                       10076
# NO STOPPING OR STANDING IN PM RUSH HOUR ZONE           9258
# NO PARKING ANYTIME                                     8195
# UNAUTHORIZED VEHICLE IN LOADING ZONE                   6714
# NO STANDING ANYTIME                                    5548
# PARK OVERTIME AT A METER                               5124
# NO STOPPING OR STANDING IN AM RUSH HOUR ZONE           4692
# NO FRONT TAGS.                                         4504
# PARK OVERTIME IN TIMED ZONE                            3958
# PARKED WITHIN 25 FEET OF A STOP SIGN                   3901
# EXPIRATION TIME ON METER RECEIPT LAPSED                3663
# FAILURE TO SECURE DC TAGS                              3498
# ...
