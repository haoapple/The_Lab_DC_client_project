# %%
import pickle
import pandas as pd
import seaborn as sns
# Out:
# Bad key "gaxes.labelsize" on line 1 in
# /Users/priya/.matplotlib/stylelib/presentation.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df = pd.read_csv('shots_spot_train.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        date  district  type_multiple_gunshots  \
# 0           0  2014-01-01         1                      14
# 1           1  2014-01-02         1                       0
# 2           2  2014-01-03         1                       0
# 3           3  2014-01-04         1                       0
# 4           4  2014-01-05         1                       0
#
#    type_single_gunshot    turnover  resolved  svc_descr_collection  \
# 0                   18  106.181818      22.0                   6.0
# 1                    0  183.420792     195.0                  27.0
# 2                    0  342.754386     109.0                  12.0
# 3                    0  224.877005     186.0                  33.0
# 4                    0  136.862069      28.0                  17.0
#
#    svc_descr_graffiti removal  svc_descr_light repair  svc_descr_maintenance  \
# 0                         0.0                     0.0                    0.0
# ...

# %%
df['district'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 13 columns):
# Unnamed: 0                        10227 non-null int64
# date                              10227 non-null object
# district                          10227 non-null int64
# type_multiple_gunshots            10227 non-null int64
# type_single_gunshot               10227 non-null int64
# turnover                          10226 non-null float64
# resolved                          10226 non-null float64
# svc_descr_collection              10226 non-null float64
# svc_descr_graffiti removal        10226 non-null float64
# svc_descr_light repair            10226 non-null float64
# svc_descr_maintenance             10226 non-null float64
# svc_descr_parking meter repair    10226 non-null float64
# svc_descr_street cleaning         10226 non-null float64
# dtypes: float64(8), int64(4), object(1)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                        0
# date                              0
# district                          0
# type_multiple_gunshots            0
# type_single_gunshot               0
# turnover                          1
# resolved                          1
# svc_descr_collection              1
# svc_descr_graffiti removal        1
# svc_descr_light repair            1
# svc_descr_maintenance             1
# svc_descr_parking meter repair    1
# svc_descr_street cleaning         1
# dtype: int64

# %%
df.corr()
# Out:
#                                 Unnamed: 0  district  type_multiple_gunshots  \
# Unnamed: 0                        1.000000  0.989743                0.155718
# district                          0.989743  1.000000                0.162148
# type_multiple_gunshots            0.155718  0.162148                1.000000
# type_single_gunshot               0.084189  0.092448                0.884326
# turnover                         -0.100257 -0.039260               -0.008326
# resolved                         -0.495402 -0.495674               -0.133720
# svc_descr_collection             -0.070570 -0.062137               -0.082159
# svc_descr_graffiti removal       -0.146256 -0.168521               -0.045949
# svc_descr_light repair           -0.250133 -0.261072               -0.099450
# svc_descr_maintenance            -0.126524 -0.120539               -0.062509
# svc_descr_parking meter repair   -0.620573 -0.593476               -0.084157
# ...

# %%
# As multiple gunshots go up, turnover goes down. As turnover goes up, gunshots go down.

# %%
#sns.heatmap(df)

# %%
turn = df[['turnover', 'type_multiple_gunshots', 'type_single_gunshot', 'svc_descr_graffiti removal','svc_descr_light repair', 'svc_descr_maintenance', 'svc_descr_street cleaning', 'svc_descr_parking meter repair']].corr()

# %%
turn
# Out:
#                                 turnover  type_multiple_gunshots  \
# turnover                        1.000000               -0.008326
# type_multiple_gunshots         -0.008326                1.000000
# type_single_gunshot             0.002272                0.884326
# svc_descr_graffiti removal     -0.040066               -0.045949
# svc_descr_light repair          0.016806               -0.099450
# svc_descr_maintenance           0.261176               -0.062509
# svc_descr_street cleaning       0.019216               -0.051534
# svc_descr_parking meter repair  0.099616               -0.084157
#
#                                 type_single_gunshot  \
# turnover                                   0.002272
# type_multiple_gunshots                     0.884326
# type_single_gunshot                        1.000000
# svc_descr_graffiti removal                -0.024901
# svc_descr_light repair                    -0.066832
# svc_descr_maintenance                     -0.038796
# ...

# %%
sns.heatmap(turn)

# %%
house = pd.read_pickle('housing_data_merge.pkl 2')

# %%
house.head(2)
# Out:
#                                               region month  year  \
# 0  Washington, DC - 16th Street Heights-Crestwood...   Jan  2014
# 1  Washington, DC - 16th Street Heights-Crestwood...   Feb  2014
#
#    median_sale_price  homes_sold  homes_sold_mom  days_on_market  \
# 0              499.0        58.0            -7.9              47
# 1              531.0        64.0            10.3              53
#
#    average_sale_to_list_mom
# 0                      -0.3
# 1                      -0.9

# %%
house.shape
# Out:
# (2904, 8)

# %%
homes = pd.read_pickle('homes_district.pkl')

# %%
homes.head(2)
# Out:
#   district  median_sale_price  homes_sold  homes_sold_mom  days_on_market  \
# 0        1         529.472441   60.267717        4.043307       19.909449
# 1        2         599.477273   51.561189        2.186014       27.157343
#
#    average_sale_to_list_mom
# 0                 -0.020079
# 1                  0.009091

# %%
homes['district'].unique()
# Out:
# array(['1', '2', '3', '4', '5', '6', '7'], dtype=object)

# %%
homes.shape
# Out:
# (7, 6)

# %%
homes
# Out:
#   district  median_sale_price  homes_sold  homes_sold_mom  days_on_market  \
# 0        1         529.472441   60.267717        4.043307       19.909449
# 1        2         599.477273   51.561189        2.186014       27.157343
# 2        3         596.480769   69.507692        1.233462       16.553846
# 3        4         492.116129   45.190323        3.447419       27.951613
# 4        5         439.884615   44.551923        2.238654       28.075000
# 5        6         238.653846   26.115385        2.698077       42.128205
# 6        7         263.845216   49.532371        2.641155       26.962576
#
#    average_sale_to_list_mom
# 0                 -0.020079
# 1                  0.009091
# 2                  0.009231
# 3                  0.000968
# 4                  0.010769
# 5                  0.029487
# 6                  0.000000

# %%
hd = pd.read_pickle('housing_data.pkl')

# %%
hd.head(2)
# Out:
#                                               region month  year  \
# 0  Washington, DC - 16th Street Heights-Crestwood...   Jan  2014
# 1  Washington, DC - 16th Street Heights-Crestwood...   Feb  2014
#
#    median_sale_price  median_sale_price_mom  median_sale_price_yoy  \
# 0              499.0                   -5.9              19.299999
# 1              531.0                    6.5              16.700001
#
#    homes_sold  homes_sold_mom  homes_sold_yoy  new_listings  \
# 0        58.0            -7.9             5.5          61.0
# 1        64.0            10.3             4.9          60.0
#
#              ...             new_listings_yoy  inventory  inventory_mom  \
# 0            ...                    38.599998       63.0           -6.0
# 1            ...                    17.600000       56.0          -11.1
#
#    inventory_yoy  days_on_market  days_on_market_mom  days_on_market_yoy  \
# 0      75.000000              47                  13                   5
# ...

# %%
merge = pd.concat([homes, df])

# %%
merge.head()
# Out:
#    Unnamed: 0  average_sale_to_list_mom date  days_on_market district  \
# 0         NaN                 -0.020079  NaN       19.909449        1
# 1         NaN                  0.009091  NaN       27.157343        2
# 2         NaN                  0.009231  NaN       16.553846        3
# 3         NaN                  0.000968  NaN       27.951613        4
# 4         NaN                  0.010769  NaN       28.075000        5
#
#    homes_sold  homes_sold_mom  median_sale_price  resolved  \
# 0   60.267717        4.043307         529.472441       NaN
# 1   51.561189        2.186014         599.477273       NaN
# 2   69.507692        1.233462         596.480769       NaN
# 3   45.190323        3.447419         492.116129       NaN
# 4   44.551923        2.238654         439.884615       NaN
#
#    svc_descr_collection  svc_descr_graffiti removal  svc_descr_light repair  \
# 0                   NaN                         NaN                     NaN
# ...

# %%
merge.isnull().sum()
# Out:
# Unnamed: 0                            7
# average_sale_to_list_mom          10227
# date                                  7
# days_on_market                    10227
# district                              0
# homes_sold                        10227
# homes_sold_mom                    10227
# median_sale_price                 10227
# resolved                              8
# svc_descr_collection                  8
# svc_descr_graffiti removal            8
# svc_descr_light repair                8
# svc_descr_maintenance                 8
# svc_descr_parking meter repair        8
# svc_descr_street cleaning             8
# turnover                              8
# type_multiple_gunshots                7
# type_single_gunshot                   7
# dtype: int64

# %%
cor = merge[['median_sale_price', 'type_multiple_gunshots']].corr()

# %%
cor
# Out:
#                         median_sale_price  type_multiple_gunshots
# median_sale_price                     1.0                     NaN
# type_multiple_gunshots                NaN                     1.0

# %%
merge.groupby('median_sale_price')['type_multiple_gunshots'].mean()
# Out:
# median_sale_price
# 238.653846   NaN
# 263.845216   NaN
# 439.884615   NaN
# 492.116129   NaN
# 529.472441   NaN
# 596.480769   NaN
# 599.477273   NaN
# Name: type_multiple_gunshots, dtype: float64

# %%
check = merge[['median_sale_price','district']].corr()

# %%
check
# Out:
#                    median_sale_price
# median_sale_price                1.0

# %%
sns.heatmap(check)

# %%
p =
